# %%
import pandas as pd
import numpy as np
from pandas import Series
#from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import re
from datetime import datetime
import matplotlib.dates as mdates
import time
import mpl_toolkits
import os,conda
from bs4 import BeautifulSoup
import glob

# %%
rain=pd.read_csv("Data__US_Cities_Annual_Rainfall.csv")
snow=pd.read_csv("Data__US_Cities_Annual_Snowfall.csv")
#sunshine=pd.read_csv("Data_North_American_Cities_by_Annual_Sunshine.csv",encoding ='latin1')
living_index=pd.read_csv("Data__US_Cities_Cost_of_Living_Index_Numbeo.csv")
job_stem=pd.read_csv("Data__US_Cities_STEM_Job_Opportunities_WalletHub.csv",encoding = "latin8")
crime=pd.read_csv("Data_US_Cities_by_Crime.csv")
rental=pd.read_csv("Data_US_Cities_MedianRentalPrice_AllHomes.csv")
#food=pd.read_csv("Data_US_Cities_by_Food.csv",encoding ='latin1')
cordinates=pd.read_csv("1000-largest-us-cities-by-population-with-geographic-coordinates.csv",sep=";")
recreation=pd.read_csv("Data_US_Cities_by_Recreation.csv")

# %%
rain.head()
# Out:
#               City_State  Average Rain Days per Year  Annual Rain (inches)  \
# 0       Atlanta, Georgia                         113                  49.7
# 1          Austin, Texas                          88                  34.2
# 2    Baltimore, Maryland                         116                  41.9
# 3    Birmingham, Alabama                         117                  53.7
# 4  Boston, Massachusetts                         126                  43.8
#
#    Annual Rain (millimeters)
# 0                       1263
# 1                        870
# 2                       1064
# 3                       1364
# 4                       1112

# %%
#rain["City"]=rain.City.str[0:-1].str.split(', ', expand = True)[0]

# %%
rain.head()
# Out:
#               City_State  Average Rain Days per Year  Annual Rain (inches)  \
# 0       Atlanta, Georgia                         113                  49.7
# 1          Austin, Texas                          88                  34.2
# 2    Baltimore, Maryland                         116                  41.9
# 3    Birmingham, Alabama                         117                  53.7
# 4  Boston, Massachusetts                         126                  43.8
#
#    Annual Rain (millimeters)
# 0                       1263
# 1                        870
# 2                       1064
# 3                       1364
# 4                       1112

# %%
rain.City_State.value_counts()
# Out:
# Indianapolis, Indiana               1
# Minneapolis, Minnesota              1
# Kansas City, Missouri               1
# Orlando, Florida                    1
# Jacksonville, Florida               1
# Houston, Texas                      1
# Los Angeles, California             1
# Denver, Colorado                    1
# New York, New York                  1
# Nashville, Tennessee                1
# Detroit, Michigan                   1
# San Antonio, Texas                  1
# Louisville, Kentucky                1
# San Diego, California               1
# Columbus, Ohio                      1
# Buffalo, New York                   1
# Oklahoma City, Oklahoma             1
# Rochester, New York                 1
# Charlotte, North Carolina           1
# San Francisco, California           1
# Washington, District of Columbia    1
# Providence, Rhode Island            1
# Philadelphia, Pennsylvania          1
# Cincinnati, Ohio                    1
# Tampa, Florida                      1
# ...

# %%
snow.head()
# Out:
#               City_State  Average Snow Days per Year  \
# 0       Atlanta, Georgia                         2.1
# 1          Austin, Texas                         0.5
# 2    Baltimore, Maryland                         9.6
# 3    Birmingham, Alabama                         0.8
# 4  Boston, Massachusetts                        22.4
#
#    Annual Snowfall (inches)  Annual Snowfall (cm)
# 0                       2.9                   7.4
# 1                       0.6                   1.5
# 2                      20.2                  51.3
# 3                       1.6                   4.1
# 4                      43.8                 111.3

# %%
snow.City_State.value_counts()
# Out:
# Indianapolis, Indiana               1
# Minneapolis, Minnesota              1
# Kansas City, Missouri               1
# Orlando, Florida                    1
# Jacksonville, Florida               1
# Houston, Texas                      1
# Los Angeles, California             1
# Denver, Colorado                    1
# New York, New York                  1
# Nashville, Tennessee                1
# Detroit, Michigan                   1
# San Antonio, Texas                  1
# Louisville, Kentucky                1
# San Diego, California               1
# Columbus, Ohio                      1
# Buffalo, New York                   1
# Oklahoma City, Oklahoma             1
# Rochester, New York                 1
# Charlotte, North Carolina           1
# San Francisco, California           1
# Washington, District of Columbia    1
# Providence, Rhode Island            1
# Philadelphia, Pennsylvania          1
# Cincinnati, Ohio                    1
# Tampa, Florida                      1
# ...

# %%
#snow["City"]=snow.City.str[0:-1].str.split(', ', expand = True)[0]
#snow.head()

# %%
#sunshine.head()

# %%
#sunshine["City"]=sunshine.City.str.capitalize()

# %%
#sunshine["City"]=sunshine.City.str[0:-1].str.split(', ', expand = True)[0]
#sunshine.head()

# %%
weather=pd.merge(rain,snow, on='City_State', how='outer')

# %%
#weather["City"]=weather.City.str.rsplit(',', expand = True)[0]

# %%
weather.isna().sum()
# Out:
# City_State                    0
# Average Rain Days per Year    0
# Annual Rain (inches)          0
# Annual Rain (millimeters)     0
# Average Snow Days per Year    0
# Annual Snowfall (inches)      0
# Annual Snowfall (cm)          0
# dtype: int64

# %%
weather.City_State.value_counts()
# Out:
# Indianapolis, Indiana               1
# Minneapolis, Minnesota              1
# Kansas City, Missouri               1
# Orlando, Florida                    1
# Jacksonville, Florida               1
# Houston, Texas                      1
# Los Angeles, California             1
# Denver, Colorado                    1
# New York, New York                  1
# Nashville, Tennessee                1
# Detroit, Michigan                   1
# San Antonio, Texas                  1
# Louisville, Kentucky                1
# San Diego, California               1
# Columbus, Ohio                      1
# Buffalo, New York                   1
# Oklahoma City, Oklahoma             1
# Rochester, New York                 1
# Charlotte, North Carolina           1
# San Francisco, California           1
# Washington, District of Columbia    1
# Providence, Rhode Island            1
# Philadelphia, Pennsylvania          1
# Cincinnati, Ohio                    1
# Tampa, Florida                      1
# ...

# %%
living_index.isna().sum()
# Out:
# City_State                        0
# Cost of Living Index              0
# Rent Index                        0
# Cost of Living Plus Rent Index    0
# Groceries Index                   0
# Restaurant Price Index            0
# Local Purchasing Power Index      0
# dtype: int64

# %%
living_index.City_State.value_counts()
# Out:
# Rochester, New York           1
# Los Angeles, California       1
# Melbourne, Florida            1
# Saint Louis, Missouri         1
# Fresno, California            1
# Colorado Springs, Colorado    1
# Portland, Oregon              1
# Columbia, South Carolina      1
# New Orleans, Louisiana        1
# Salem, Oregon                 1
# Fort Worth, Texas             1
# Little Rock, Arkansas         1
# Milwaukee, Wisconsin          1
# College Station, Texas        1
# Springfield, Missouri         1
# Grand Rapids, Michigan        1
# Shreveport, Louisiana         1
# Bloomington, Indiana          1
# Bellingham, Washington        1
# Memphis, Tennessee            1
# Portland, Maine               1
# Raleigh, North Carolina       1
# Detroit, Michigan             1
# Athens, Georgia               1
# Seattle, Washington           1
# Bellevue, Washington          1
# Brooklyn, New York            1
# Indianapolis, Indiana         1
# Tulsa, Oklahoma               1
# ...

# %%
living_index[living_index.duplicated(['City_State'], keep=False)] # no repeated values
# Out:
# Empty DataFrame
# Columns: [City_State, Cost of Living Index, Rent Index, Cost of Living Plus Rent Index, Groceries Index, Restaurant Price Index, Local Purchasing Power Index]
# Index: []

# %%
living_index.head()
# Out:
#                   City_State  Cost of Living Index  Rent Index  \
# 0         New York, New York                100.00      100.00
# 1  San Francisco, California                 97.84      115.36
# 2          Anchorage, Alaska                 94.99       40.12
# 3           Honolulu, Hawaii                 94.15       62.82
# 4         Brooklyn, New York                 93.79       76.24
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                          100.00           100.00                  100.00
# 1                          106.29           107.52                   91.06
# 2                           68.53           101.18                   84.55
# 3                           79.04           104.69                   82.86
# 4                           85.33            92.73                  100.58
#
#    Local Purchasing Power Index
# 0                        100.00
# 1                         92.96
# 2                        124.92
# ...

# %%
liv_weather=pd.merge(weather,living_index, on='City_State', how='outer')

# %%
liv_weather.head()
# Out:
#               City_State  Average Rain Days per Year  Annual Rain (inches)  \
# 0       Atlanta, Georgia                       113.0                  49.7
# 1          Austin, Texas                        88.0                  34.2
# 2    Baltimore, Maryland                       116.0                  41.9
# 3    Birmingham, Alabama                       117.0                  53.7
# 4  Boston, Massachusetts                       126.0                  43.8
#
#    Annual Rain (millimeters)  Average Snow Days per Year  \
# 0                     1263.0                         2.1
# 1                      870.0                         0.5
# 2                     1064.0                         9.6
# 3                     1364.0                         0.8
# 4                     1112.0                        22.4
#
#    Annual Snowfall (inches)  Annual Snowfall (cm)  Cost of Living Index  \
# 0                       2.9                   7.4                 74.97
# ...

# %%
liv_weather.isna().sum() #Number of Null values as of now weather data + living_index data
# Out:
# City_State                         0
# Average Rain Days per Year        84
# Annual Rain (inches)              84
# Annual Rain (millimeters)         84
# Average Snow Days per Year        84
# Annual Snowfall (inches)          84
# Annual Snowfall (cm)              84
# Cost of Living Index               3
# Rent Index                         3
# Cost of Living Plus Rent Index     3
# Groceries Index                    3
# Restaurant Price Index             3
# Local Purchasing Power Index       3
# dtype: int64

# %%
liv_weather[liv_weather.duplicated(['City_State'], keep=False)] # no repeated values
# Out:
# Empty DataFrame
# Columns: [City_State, Average Rain Days per Year, Annual Rain (inches), Annual Rain (millimeters), Average Snow Days per Year, Annual Snowfall (inches), Annual Snowfall (cm), Cost of Living Index, Rent Index, Cost of Living Plus Rent Index, Groceries Index, Restaurant Price Index, Local Purchasing Power Index]
# Index: []

# %%
liv_weather
# Out:
#                         City_State  Average Rain Days per Year  \
# 0                 Atlanta, Georgia                       113.0
# 1                    Austin, Texas                        88.0
# 2              Baltimore, Maryland                       116.0
# 3              Birmingham, Alabama                       117.0
# 4            Boston, Massachusetts                       126.0
# 5                Buffalo, New York                       167.0
# 6        Charlotte, North Carolina                       110.0
# 7                Chicago, Illinois                       124.0
# 8                 Cincinnati, Ohio                       137.0
# 9                  Cleveland, Ohio                       155.0
# 10                  Columbus, Ohio                       139.0
# 11                   Dallas, Texas                        81.0
# 12                Denver, Colorado                        87.0
# 13               Detroit, Michigan                       135.0
# ...

# %%
job_stem.head()
# Out:
#                  City_State  STEM Job Opportunities Total Rank  \
# 0       Seattle, Washington                              73.60
# 1     Boston, Massachusetts                              71.94
# 2  Pittsburgh, Pennsylvania                              65.90
# 3             Austin, Texas                              65.15
# 4    Minneapolis, Minnesota                              64.95
#
#    STEM Job opportunities rank  STEM Friendliness rank  Quality of life rank
# 0                            2                       4                    15
# 1                            7                       1                    43
# 2                           12                      11                     9
# 3                            6                       8                    27
# 4                           19                       6                    17

# %%
job_stem.City_State = job_stem.City_State.str.replace('\s{2,}', '')

# %%
job_stem.head()
# Out:
#                  City_State  STEM Job Opportunities Total Rank  \
# 0       Seattle, Washington                              73.60
# 1     Boston, Massachusetts                              71.94
# 2  Pittsburgh, Pennsylvania                              65.90
# 3             Austin, Texas                              65.15
# 4    Minneapolis, Minnesota                              64.95
#
#    STEM Job opportunities rank  STEM Friendliness rank  Quality of life rank
# 0                            2                       4                    15
# 1                            7                       1                    43
# 2                           12                      11                     9
# 3                            6                       8                    27
# 4                           19                       6                    17

# %%
job_stem.City_State.value_counts()
# Out:
# Rochester, New York           1
# Albuquerque, New Mexico       1
# Colorado Springs, Colorado    1
# Greensboro, North Carolina    1
# Lakeland, Florida             1
# New Orleans, Louisiana        1
# Wichita, Kansas               1
# Little Rock, Arkansas         1
# Milwaukee, Wisconsin          1
# Grand Rapids, Michigan        1
# Columbia, South Carolina      1
# Memphis, Tennessee            1
# Raleigh, North Carolina       1
# Dallas, Texas                 1
# Jackson, Mississippi          1
# Detroit, Michigan             1
# St. Louis, Missouri           1
# Seattle, Washington           1
# Tucson, Arizona               1
# Portland, Oregon              1
# Salt Lake City, Utah          1
# Denver, Colorado              1
# Boise, Idaho                  1
# San Diego, California         1
# Fresno, California            1
# Richmond, Virginia            1
# Tampa, Florida                1
# Scranton, Pennsylvania        1
# Cincinnati, Ohio              1
# ...

# %%
job_stem[job_stem.duplicated(['City_State'], keep=False)] #had multiple duplicate values
# Out:
# Empty DataFrame
# Columns: [City_State, STEM Job Opportunities Total Rank, STEM Job opportunities rank, STEM Friendliness rank, Quality of life rank]
# Index: []

# %%
job_stem.dropna(inplace=True)

# %%
job_stem.City_State.str.lstrip()
# Out:
# 0            Seattle, Washington
# 1          Boston, Massachusetts
# 2       Pittsburgh, Pennsylvania
# 3                  Austin, Texas
# 4         Minneapolis, Minnesota
# 5             Madison, Wisconsin
# 6           Salt Lake City, Utah
# 7     Springfield, Massachusetts
# 8              Chicago, Illinois
# 9               Atlanta, Georgia
# 10              Cincinnati, Ohio
# 11     San Francisco, California
# 12                Columbus, Ohio
# 13              Denver, Colorado
# 14         San Diego, California
# 15        Sacramento, California
# 16    Colorado Springs, Colorado
# 17      Worcester, Massachusetts
# 18            Richmond, Virginia
# 19          San Jose, California
# 20                Houston, Texas
# 21       Raleigh, North Carolina
# 22           St. Louis, Missouri
# 23         Hartford, Connecticut
# 24                  Dayton, Ohio
# 25        Grand Rapids, Michigan
# 26              Orlando, Florida
# 27               Tucson, Arizona
# ...

# %%
job_stem[job_stem["City_State"]=="Boston, Massachusetts"]
# Out:
#               City_State  STEM Job Opportunities Total Rank  \
# 1  Boston, Massachusetts                              71.94
#
#    STEM Job opportunities rank  STEM Friendliness rank  Quality of life rank
# 1                            7                       1                    43

# %%
liv_weather.head()
# Out:
#               City_State  Average Rain Days per Year  Annual Rain (inches)  \
# 0       Atlanta, Georgia                       113.0                  49.7
# 1          Austin, Texas                        88.0                  34.2
# 2    Baltimore, Maryland                       116.0                  41.9
# 3    Birmingham, Alabama                       117.0                  53.7
# 4  Boston, Massachusetts                       126.0                  43.8
#
#    Annual Rain (millimeters)  Average Snow Days per Year  \
# 0                     1263.0                         2.1
# 1                      870.0                         0.5
# 2                     1064.0                         9.6
# 3                     1364.0                         0.8
# 4                     1112.0                        22.4
#
#    Annual Snowfall (inches)  Annual Snowfall (cm)  Cost of Living Index  \
# 0                       2.9                   7.4                 74.97
# ...

# %%
liv_weather.City_State.unique()
# Out:
# array(['Atlanta, Georgia', 'Austin, Texas', 'Baltimore, Maryland',
#        'Birmingham, Alabama', 'Boston, Massachusetts',
#        'Buffalo, New York', 'Charlotte, North Carolina',
#        'Chicago, Illinois', 'Cincinnati, Ohio', 'Cleveland, Ohio',
#        'Columbus, Ohio', 'Dallas, Texas', 'Denver, Colorado',
#        'Detroit, Michigan', 'Hartford, Connecticut', 'Houston, Texas',
#        'Indianapolis, Indiana', 'Jacksonville, Florida',
#        'Kansas City, Missouri', 'Las Vegas, Nevada',
#        'Los Angeles, California', 'Louisville, Kentucky',
#        'Memphis, Tennessee', 'Miami, Florida', 'Milwaukee, Wisconsin',
#        'Minneapolis, Minnesota', 'Nashville, Tennessee',
#        'New Orleans, Louisiana', 'New York, New York',
#        'Oklahoma City, Oklahoma', 'Orlando, Florida',
#        'Philadelphia, Pennsylvania', 'Phoenix, Arizona',
#        'Pittsburgh, Pennsylvania', 'Portland, Oregon',
#        'Providence, Rhode Island', 'Raleigh, North Carolina',
# ...

# %%
job_wet_liv=pd.merge(liv_weather,job_stem,on='City_State', how='outer')

# %%
job_wet_liv.head()
# Out:
#               City_State  Average Rain Days per Year  Annual Rain (inches)  \
# 0       Atlanta, Georgia                       113.0                  49.7
# 1          Austin, Texas                        88.0                  34.2
# 2    Baltimore, Maryland                       116.0                  41.9
# 3    Birmingham, Alabama                       117.0                  53.7
# 4  Boston, Massachusetts                       126.0                  43.8
#
#    Annual Rain (millimeters)  Average Snow Days per Year  \
# 0                     1263.0                         2.1
# 1                      870.0                         0.5
# 2                     1064.0                         9.6
# 3                     1364.0                         0.8
# 4                     1112.0                        22.4
#
#    Annual Snowfall (inches)  Annual Snowfall (cm)  Cost of Living Index  \
# 0                       2.9                   7.4                 74.97
# ...

# %%
job_wet_liv.isna().sum() #Number of Null values as of now weather data + living_index data+job data
# Out:
# City_State                             0
# Average Rain Days per Year           105
# Annual Rain (inches)                 105
# Annual Rain (millimeters)            105
# Average Snow Days per Year           105
# Annual Snowfall (inches)             105
# Annual Snowfall (cm)                 105
# Cost of Living Index                  24
# Rent Index                            24
# Cost of Living Plus Rent Index        24
# Groceries Index                       24
# Restaurant Price Index                24
# Local Purchasing Power Index          24
# STEM Job Opportunities Total Rank     56
# STEM Job opportunities rank           56
# STEM Friendliness rank                56
# Quality of life rank                  56
# dtype: int64

# %%
job_wet_liv[job_wet_liv.duplicated(['City_State'], keep=False)] #No City has been repeated
# Out:
# Empty DataFrame
# Columns: [City_State, Average Rain Days per Year, Annual Rain (inches), Annual Rain (millimeters), Average Snow Days per Year, Annual Snowfall (inches), Annual Snowfall (cm), Cost of Living Index, Rent Index, Cost of Living Plus Rent Index, Groceries Index, Restaurant Price Index, Local Purchasing Power Index, STEM Job Opportunities Total Rank, STEM Job opportunities rank, STEM Friendliness rank, Quality of life rank]
# Index: []

# %%
job_wet_liv.City_State.unique()
# Out:
# array(['Atlanta, Georgia', 'Austin, Texas', 'Baltimore, Maryland',
#        'Birmingham, Alabama', 'Boston, Massachusetts',
#        'Buffalo, New York', 'Charlotte, North Carolina',
#        'Chicago, Illinois', 'Cincinnati, Ohio', 'Cleveland, Ohio',
#        'Columbus, Ohio', 'Dallas, Texas', 'Denver, Colorado',
#        'Detroit, Michigan', 'Hartford, Connecticut', 'Houston, Texas',
#        'Indianapolis, Indiana', 'Jacksonville, Florida',
#        'Kansas City, Missouri', 'Las Vegas, Nevada',
#        'Los Angeles, California', 'Louisville, Kentucky',
#        'Memphis, Tennessee', 'Miami, Florida', 'Milwaukee, Wisconsin',
#        'Minneapolis, Minnesota', 'Nashville, Tennessee',
#        'New Orleans, Louisiana', 'New York, New York',
#        'Oklahoma City, Oklahoma', 'Orlando, Florida',
#        'Philadelphia, Pennsylvania', 'Phoenix, Arizona',
#        'Pittsburgh, Pennsylvania', 'Portland, Oregon',
#        'Providence, Rhode Island', 'Raleigh, North Carolina',
# ...

# %%
job_wet_liv.to_excel("py_pro.xlsx","sheet1")

# %%
crime.head()
# Out:
#                 City_State  Total Violent Crime  \
# 0  Albuquerque, New Mexico                965.8
# 1      Anaheim, California                363.7
# 2        Anchorage, Alaska               1070.9
# 3         Arlington, Texas                502.1
# 4         Atlanta, Georgia               1119.6
#
#    Murder and Nonnegligent Manslaughter   Rape  Robbery  Aggravated Assault  \
# 0                                   7.7   72.2    301.2               584.8
# 1                                   5.2   36.9    125.6               196.0
# 2                                   8.6  171.6    206.1               684.5
# 3                                   2.1   53.7    136.5               309.9
# 4                                  20.2   36.6    429.3               633.5
#
#    Total Property Crime  Burglary  Larceny-Theft  Motor Vehicle Theft
# 0                6073.2    1071.2         4076.7                925.3
# 1                2872.3     422.4         1972.4                477.6
# ...

# %%
crime.City_State.value_counts()
# Out:
# Colorado Springs, Colorado               1
# Columbus, Ohio                           1
# Arlington, Texas                         1
# Fort Worth, Texas                        1
# Baltimore, Maryland                      1
# San Antonio, Texas                       1
# Laredo, Texas                            1
# Honolulu, Hawaii                         1
# St. Petersburg, Florida                  1
# Omaha, Nebraska                          1
# Jacksonville, Florida                    1
# Denver, Colorado                         1
# Los Angeles, California                  1
# Riverside, California                    1
# Chandler, Arizona                        1
# Houston, Texas                           1
# Nashville Metropolitan, Tennessee        1
# Mobile2, Alabama                         1
# New York, New York                       1
# Wichita, Kansas                          1
# Oklahoma City, Oklahoma                  1
# Plano, Texas                             1
# ...

# %%
crime_job=pd.merge(job_wet_liv,crime,on='City_State', how='outer')

# %%
crime_job.head()
# Out:
#               City_State  Average Rain Days per Year  Annual Rain (inches)  \
# 0       Atlanta, Georgia                       113.0                  49.7
# 1          Austin, Texas                        88.0                  34.2
# 2    Baltimore, Maryland                       116.0                  41.9
# 3    Birmingham, Alabama                       117.0                  53.7
# 4  Boston, Massachusetts                       126.0                  43.8
#
#    Annual Rain (millimeters)  Average Snow Days per Year  \
# 0                     1263.0                         2.1
# 1                      870.0                         0.5
# 2                     1064.0                         9.6
# 3                     1364.0                         0.8
# 4                     1112.0                        22.4
#
#    Annual Snowfall (inches)  Annual Snowfall (cm)  Cost of Living Index  \
# 0                       2.9                   7.4                 74.97
# ...

# %%
crime_job.City_State.value_counts()
# Out:
# Jackson, Mississippi             1
# St. Louis, Missouri              1
# Springfield, Missouri            1
# College Station, Texas           1
# Milwaukee, Wisconsin             1
# Little Rock, Arkansas            1
# Fort Worth, Texas                1
# Salem, Oregon                    1
# New Orleans, Louisiana           1
# Columbia, South Carolina         1
# Portland, Oregon                 1
# Los Angeles, California          1
# Winston-Salem, North Carolina    1
# Colorado Springs, Colorado       1
# Fresno, California               1
# Saint Louis, Missouri            1
# Melbourne, Florida               1
# Albuquerque, New Mexico          1
# Mesa, Arizona                    1
# Lakeland, Florida                1
# Grand Rapids, Michigan           1
# Shreveport, Louisiana            1
# Bloomington, Indiana             1
# Arlington, Virginia              1
# Boise, Idaho                     1
# Lexington, Kentucky              1
# Fort Myers, Florida              1
# ...

# %%
crime_job.City_State.unique()
# Out:
# array(['Atlanta, Georgia', 'Austin, Texas', 'Baltimore, Maryland',
#        'Birmingham, Alabama', 'Boston, Massachusetts',
#        'Buffalo, New York', 'Charlotte, North Carolina',
#        'Chicago, Illinois', 'Cincinnati, Ohio', 'Cleveland, Ohio',
#        'Columbus, Ohio', 'Dallas, Texas', 'Denver, Colorado',
#        'Detroit, Michigan', 'Hartford, Connecticut', 'Houston, Texas',
#        'Indianapolis, Indiana', 'Jacksonville, Florida',
#        'Kansas City, Missouri', 'Las Vegas, Nevada',
#        'Los Angeles, California', 'Louisville, Kentucky',
#        'Memphis, Tennessee', 'Miami, Florida', 'Milwaukee, Wisconsin',
#        'Minneapolis, Minnesota', 'Nashville, Tennessee',
#        'New Orleans, Louisiana', 'New York, New York',
#        'Oklahoma City, Oklahoma', 'Orlando, Florida',
#        'Philadelphia, Pennsylvania', 'Phoenix, Arizona',
#        'Pittsburgh, Pennsylvania', 'Portland, Oregon',
#        'Providence, Rhode Island', 'Raleigh, North Carolina',
# ...

# %%
crime_job.to_excel("final.xlsx","sheet1")

# %%
crime_job.City_State.value_counts()
# Out:
# Jackson, Mississippi             1
# St. Louis, Missouri              1
# Springfield, Missouri            1
# College Station, Texas           1
# Milwaukee, Wisconsin             1
# Little Rock, Arkansas            1
# Fort Worth, Texas                1
# Salem, Oregon                    1
# New Orleans, Louisiana           1
# Columbia, South Carolina         1
# Portland, Oregon                 1
# Los Angeles, California          1
# Winston-Salem, North Carolina    1
# Colorado Springs, Colorado       1
# Fresno, California               1
# Saint Louis, Missouri            1
# Melbourne, Florida               1
# Albuquerque, New Mexico          1
# Mesa, Arizona                    1
# Lakeland, Florida                1
# Grand Rapids, Michigan           1
# Shreveport, Louisiana            1
# Bloomington, Indiana             1
# Arlington, Virginia              1
# Boise, Idaho                     1
# Lexington, Kentucky              1
# Fort Myers, Florida              1
# ...

# %%
crime_job.nunique()
# Out:
# City_State                              172
# Average Rain Days per Year               42
# Annual Rain (inches)                     47
# Annual Rain (millimeters)                50
# Average Snow Days per Year               41
# Annual Snowfall (inches)                 40
# Annual Snowfall (cm)                     40
# Cost of Living Index                    131
# Rent Index                              129
# Cost of Living Plus Rent Index          131
# Groceries Index                         128
# Restaurant Price Index                  130
# Local Purchasing Power Index            132
# STEM Job Opportunities Total Rank       100
# STEM Job opportunities rank              99
# STEM Friendliness rank                   86
# Quality of life rank                     99
# Total Violent Crime                      83
# Murder and Nonnegligent Manslaughter     66
# Rape                                     78
# Robbery                                  83
# ...

# %%
crime_job.shape
# Out:
# (172, 26)

# %%
crime_job.dropna(thresh=18)
# Out:
#                      City_State  Average Rain Days per Year  \
# 0              Atlanta, Georgia                       113.0
# 1                 Austin, Texas                        88.0
# 2           Baltimore, Maryland                       116.0
# 4         Boston, Massachusetts                       126.0
# 5             Buffalo, New York                       167.0
# 7             Chicago, Illinois                       124.0
# 8              Cincinnati, Ohio                       137.0
# 9               Cleveland, Ohio                       155.0
# 10               Columbus, Ohio                       139.0
# 11                Dallas, Texas                        81.0
# 12             Denver, Colorado                        87.0
# 13            Detroit, Michigan                       135.0
# 15               Houston, Texas                       104.0
# 16        Indianapolis, Indiana                       129.0
# 17        Jacksonville, Florida                       114.0
# ...

# %%
crime_job.isna().sum()
# Out:
# City_State                                0
# Average Rain Days per Year              121
# Annual Rain (inches)                    121
# Annual Rain (millimeters)               121
# Average Snow Days per Year              121
# Annual Snowfall (inches)                121
# Annual Snowfall (cm)                    121
# Cost of Living Index                     40
# Rent Index                               40
# Cost of Living Plus Rent Index           40
# Groceries Index                          40
# Restaurant Price Index                   40
# Local Purchasing Power Index             40
# STEM Job Opportunities Total Rank        72
# STEM Job opportunities rank              72
# STEM Friendliness rank                   72
# Quality of life rank                     72
# Total Violent Crime                      89
# Murder and Nonnegligent Manslaughter     89
# Rape                                     89
# Robbery                                  89
# ...

# %%
crime_job[crime_job["City_State"]=="Boston, Massachusetts"]
# Out:
#               City_State  Average Rain Days per Year  Annual Rain (inches)  \
# 4  Boston, Massachusetts                       126.0                  43.8
#
#    Annual Rain (millimeters)  Average Snow Days per Year  \
# 4                     1112.0                        22.4
#
#    Annual Snowfall (inches)  Annual Snowfall (cm)  Cost of Living Index  \
# 4                      43.8                 111.3                 87.05
#
#    Rent Index  Cost of Living Plus Rent Index         ...           \
# 4       78.72                           83.03         ...
#
#    Quality of life rank  Total Violent Crime  \
# 4                  43.0                706.8
#
#    Murder and Nonnegligent Manslaughter  Rape  Robbery  Aggravated Assault  \
# 4                                   5.7  36.1    233.1               431.9
#
#    Total Property Crime  Burglary  Larceny-Theft  Motor Vehicle Theft
# 4                2316.1     354.3         1769.5                192.3
#
# [1 rows x 26 columns]

# %%
cordinates=pd.read_csv("1000-largest-us-cities-by-population-with-geographic-coordinates.csv",sep=";")

# %%
cordinates.head()
# Out:
#                   City  Rank          State  Growth From 2000 to 2013  \
# 0  South San Francisco   522     California                       9.1
# 1          Aliso Viejo   741     California                      25.4
# 2           Rapid City   479   South Dakota                      17.9
# 3          Coon Rapids   563      Minnesota                       0.6
# 4               Malden   585  Massachusetts                       7.4
#
#    Population               Coordinates
# 0       66174   37.654656, -122.4077498
# 1       50175  33.5676842, -117.7256083
# 2       70812  44.0805434, -103.2310149
# 3       62103   45.1732394, -93.3030063
# 4       60509    42.4250964, -71.066163

# %%
cordinates['City_State'] = cordinates[['City', 'State']].apply(lambda x: ', '.join(x), axis=1)

# %%
cordinates.drop(columns="City",inplace=True)

# %%
cordinates.drop(columns="State",inplace=True)

# %%
cordinates.drop(columns="Rank",inplace=True)

# %%
cordinates.drop(columns="Population",inplace=True)

# %%
cordinates[cordinates["City_State"]=="Boston, Massachusetts"]
# Out:
#      Growth From 2000 to 2013              Coordinates             City_State
# 935                       9.4  42.3600825, -71.0588801  Boston, Massachusetts

# %%
cordinates.City_State.value_counts()
# Out:
# Tulare, California              1
# Bremerton, Washington           1
# Beloit, Wisconsin               1
# Lee's Summit, Missouri          1
# Palm Bay, Florida               1
# Monroe, Louisiana               1
# San Antonio, Texas              1
# Norman, Oklahoma                1
# Minneapolis, Minnesota          1
# Monrovia, California            1
# Hampton, Virginia               1
# Jersey City, New Jersey         1
# Sarasota, Florida               1
# Deltona, Florida                1
# Bolingbrook, Illinois           1
# Charlotte, North Carolina       1
# Eden Prairie, Minnesota         1
# Columbia, Missouri              1
# Oklahoma City, Oklahoma         1
# Menifee, California             1
# Cedar Hill, Texas               1
# Boynton Beach, Florida          1
# Johnson City, Tennessee         1
# Kirkland, Washington            1
# Manteca, California             1
# La Mirada, California           1
# Muncie, Indiana                 1
# ...

# %%
final=pd.merge(crime_job,cordinates,on='City_State', how='outer')

# %%
final.City_State.value_counts()
# Out:
# Tulare, California              1
# Columbia, Missouri              1
# Saint Paul, Minnesota           1
# Monroe, Louisiana               1
# San Antonio, Texas              1
# Norman, Oklahoma                1
# Germantown, Tennessee           1
# Monrovia, California            1
# Hampton, Virginia               1
# Jersey City, New Jersey         1
# Sarasota, Florida               1
# Deltona, Florida                1
# Bolingbrook, Illinois           1
# Bremerton, Washington           1
# Rosemead, California            1
# Oklahoma City, Oklahoma         1
# Lee's Summit, Missouri          1
# Menifee, California             1
# Cedar Hill, Texas               1
# Boynton Beach, Florida          1
# Cedar Park, Texas               1
# Johnson City, Tennessee         1
# Kirkland, Washington            1
# Manteca, California             1
# La Mirada, California           1
# Muncie, Indiana                 1
# Skokie, Illinois                1
# ...

# %%
final[final["City_State"]=="Boston,Massachusetts"]
# Out:
# Empty DataFrame
# Columns: [City_State, Average Rain Days per Year, Annual Rain (inches), Annual Rain (millimeters), Average Snow Days per Year, Annual Snowfall (inches), Annual Snowfall (cm), Cost of Living Index, Rent Index, Cost of Living Plus Rent Index, Groceries Index, Restaurant Price Index, Local Purchasing Power Index, STEM Job Opportunities Total Rank, STEM Job opportunities rank, STEM Friendliness rank, Quality of life rank, Total Violent Crime, Murder and Nonnegligent Manslaughter, Rape, Robbery, Aggravated Assault, Total Property Crime, Burglary, Larceny-Theft, Motor Vehicle Theft, Growth From 2000 to 2013, Coordinates]
# Index: []
#
# [0 rows x 28 columns]

# %%
final.City_State.value_counts()
# Out:
# Tulare, California              1
# Columbia, Missouri              1
# Saint Paul, Minnesota           1
# Monroe, Louisiana               1
# San Antonio, Texas              1
# Norman, Oklahoma                1
# Germantown, Tennessee           1
# Monrovia, California            1
# Hampton, Virginia               1
# Jersey City, New Jersey         1
# Sarasota, Florida               1
# Deltona, Florida                1
# Bolingbrook, Illinois           1
# Bremerton, Washington           1
# Rosemead, California            1
# Oklahoma City, Oklahoma         1
# Lee's Summit, Missouri          1
# Menifee, California             1
# Cedar Hill, Texas               1
# Boynton Beach, Florida          1
# Cedar Park, Texas               1
# Johnson City, Tennessee         1
# Kirkland, Washington            1
# Manteca, California             1
# La Mirada, California           1
# Muncie, Indiana                 1
# Skokie, Illinois                1
# ...

# %%
recreation.head()
# Out:
#               City_State  Recreation Score
# 0       Orlando, Florida             60.03
# 1  Las Vegas, New Mexico             57.47
# 2  San Diego, California             55.15
# 3       Cincinnati, Ohio             53.68
# 4         Tampa, Florida             53.02

# %%
recreation.City_State.value_counts()
# Out:
# Santa Ana, California          1
# Atlanta, Georgia               1
# Madison, Puerto Rico           1
# Fresno, California             1
# North Las Vegas, New Mexico    1
# Charlotte, Montana             1
# Colorado Springs, Colorado     1
# Phoenix, Arkansas              1
# Portland, Oregon               1
# St. Louis, Missouri            1
# Sacramento, California         1
# Wichita, Kansas                1
# Kansas City, Missouri          1
# Glendale, Arkansas             1
# Baltimore, Massachusetts       1
# Toledo, Ohio                   1
# Memphis, Tennessee             1
# Albuquerque, New Mexico        1
# Detroit, Michigan              1
# Virginia Beach, Puerto Rico    1
# Durham, Montana                1
# Indianapolis, Indiana          1
# Denver, Colorado               1
# Fort Worth, Texas              1
# Tampa, Florida                 1
# Milwaukee, Puerto Rico         1
# Washington, Connecticut        1
# Plano, Texas                   1
# ...

# %%
final=pd.merge(final,recreation,on='City_State', how='outer')

# %%
final.City_State.value_counts()
# Out:
# Tulare, California              1
# Port Orange, Florida            1
# Thornton, Colorado              1
# Beloit, Wisconsin               1
# Greeley, Colorado               1
# Lee's Summit, Missouri          1
# Palm Bay, Florida               1
# Saint Paul, Minnesota           1
# Monroe, Louisiana               1
# San Antonio, Texas              1
# Norman, Oklahoma                1
# Germantown, Tennessee           1
# Monrovia, California            1
# Hampton, Virginia               1
# Jersey City, New Jersey         1
# Sarasota, Florida               1
# Deltona, Florida                1
# Bolingbrook, Illinois           1
# Bremerton, Washington           1
# Rosemead, California            1
# Columbia, Missouri              1
# Oklahoma City, Oklahoma         1
# Mesa, Arkansas                  1
# Menifee, California             1
# Cedar Hill, Texas               1
# Boynton Beach, Florida          1
# Cedar Park, Texas               1
# ...

# %%
final.to_excel("final.xlsx","sheet1")
